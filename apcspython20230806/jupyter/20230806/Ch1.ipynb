# %% [markdown]
# # Python第一課
# ## 輸出數字

# %%
print(20)
# Out:
# 20

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Vivin")
print(123)
print(1.4142)

print(3.1415,2.71828)

print(4,5,6,sep=",")
print(1,2,3,sep="-")

'''
輸出A不斷行
B斷行
'''
print("A",end="")#不斷行
print("B")
print("C")
# Out:
# Vivin
# 123
# 1.4142
# 3.1415 2.71828
# 4,5,6
# 1-2-3
# AB
# C

# %%
age1 = 18
#2age = 15
print(age1)
年齡3 = 17
print(年齡3)
# Out:
# 18
# 17

# %%
salary = 25000
commision = 1000
sales = 18
pay = salary + commision * sales
print(pay)
# Out:
# 43000

# %%
price = 250
print(price)

price = 199
print(price)

price = 150.99
print(price)

price = "金額"
print(price)
# Out:
# 250
# 199
# 150.99
# 金額

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a1 = 10
a2 = 6

a3 = a1 + a2
print(a3)
a3 = a1 - a2
print(a3)
a3 = a1 * a2
print(a3)
a3 = a1 /a2 # 有小數點
print(a3)
a3 = a1 // a2 #無小數點
print(a3)
a3 = a1 % a2 #取餘數
print(a3)

a4 = 2
print(a4 ** 3) #算次方 2 * 2 * 2

x =  9 + 3 * 2 **2 - 1
#    9+  3 *  4    - 1
#    9 + 12 - 1
#     21 - 1
print(x)
# Out:
# 16
# 4
# 60
# 1.6666666666666667
# 1
# 4
# 8
# 20

# %% [markdown]
# ## 作業
# ![image.png](attachment:image.png)
